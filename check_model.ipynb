# %%
import pandas as pd
import numpy as np
import re
from pymorphy2 import MorphAnalyzer
from stop_words import get_stop_words
import string

import pymorphy2
morph = pymorphy2.MorphAnalyzer()

from scipy import spatial

import pickle

from transformers import TFAutoModel, AutoTokenizer

import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

from scipy.cluster.hierarchy import linkage, dendrogram

from tqdm import tqdm

morpher = MorphAnalyzer()
sw = set(get_stop_words("ru"))
exclude = set(string.punctuation)

bert = TFAutoModel.from_pretrained("Geotrend/bert-base-ru-cased")
tokenizer = AutoTokenizer.from_pretrained("Geotrend/bert-base-ru-cased")
# Out:
# Some layers from the model checkpoint at Geotrend/bert-base-ru-cased were not used when initializing TFBertModel: ['mlm___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at Geotrend/bert-base-ru-cased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
df = pd.read_pickle('df_km.pickle')

# %%
df.sample()
# Out:
#           id                  name  \
# 29629  19242  Минестроне примавера
#
#                                                 embeding  km_30  km_60  km_90  \
# 29629  [-0.43742597103118896, 0.16899362206459045, -0...     24      0     23
#
#        km_120  km_150  km_180  km_210  ...  km_720  km_750  km_780  km_810  \
# 29629      82      45       6     130  ...     254     192     149     554
#
#        km_840  km_870  km_900  km_930  km_960  km_990
# 29629     602     799     537     206     137     655
#
# [1 rows x 36 columns]

# %%
def load_km(number):
    km = pickle.load(open(f"models/kmeans_{number}_cl.pkl", "rb"))
    return km

# %%
# обработка текста
def pipline(text, number):
    lem = []
    pattern = r'[^a-zA-Zа-яА-Я0-9 ]'
    text = text.lower()
    text = text.strip()
    text = re.sub(pattern, '', text)
    text = ' '.join(i for i in text.split() if i not in sw)
    for word in text.split():
        p = morph.parse(word)[0]
        lem.append(p.normal_form)
    text = ' '.join(lem)
    tok = tokenizer([text], 
               max_length=20, truncation=True, padding='max_length', return_token_type_ids=False, return_tensors='tf')
    text = bert(**tok)[1].numpy().tolist()[0]
    km = load_km(number)
    predict = km.predict([text])[0]
    pred = df[df[f'km_{number}'] == predict]
    name = f'km_{number}'
    return pred, name

# %%
texts = ['суп', 'шашлык', 'печенье', 'картошка', 'рыба', 'макароны', 'салат']

# %%
# %%time
# смотрю какое кол-во кластеров больше подходит
res = {}
list_ = []

for number in range(30, 1010, 30):
    subreport = []
    report = []
    true_pred = 0
    for text in texts:
        count = 0
        count_true = 0
        for i in df[['id','name']].iterrows():
            if text in i[1][1].lower():
                count+=1
        res[text] = count
        text1 = f'Всего слово {text} встрречается в df {count} раз'
        print(text1)
        predict, name = pipline(text, number)
        text2 = f'{name} нашел {predict.shape[0]} совпадений'
        print(text2)
        for j in predict[['id','name']].iterrows():
            if text in j[1][1].lower():
                count_true += 1
        text3 = f'из {count} строк в {count_true} действительно есть слово {text}'
        print(text3)
        pred_false = count - count_true
        text4 = f'{pred_false} неправильно предсказаных'
        print(text4)
        print('\n','*' * 50,'\n')
        true_pred += count_true
        
        
        subreport.append(text1)
        subreport.append(text2)
        subreport.append(text3)
        subreport.append(text4)
        subreport.append('\n\n')
        
#         report = '\n'.join(subreport)
        with open("report.txt", "a") as myfile:
            myfile.write('\n'.join(subreport))
    print('\n','*' * 50,'\n')
    print(f'всего правильно предсказано:  {true_pred}')
    print('\n','*' * 50,'\n')
    res[name] = true_pred
sort_dict = sorted(res.items(), key=lambda kv: kv[1], reverse=True)
print(sort_dict)
with open("true_pred.txt", "a") as myfile:
    myfile.write(str(sort_dict))
# Out:
# Всего слово суп встрречается в df 1935 раз
# km_30 нашел 1327 совпадений
# из 1935 строк в 19 действительно есть слово суп
# 1916 неправильно предсказаных
#
#  **************************************************
#
# Всего слово шашлык встрречается в df 138 раз
# km_30 нашел 1327 совпадений
# из 138 строк в 5 действительно есть слово шашлык
# 133 неправильно предсказаных
#
#  **************************************************
#
# Всего слово печенье встрречается в df 585 раз
# km_30 нашел 510 совпадений
# из 585 строк в 177 действительно есть слово печенье
# 408 неправильно предсказаных
#
#  **************************************************
#
# Всего слово картошка встрречается в df 72 раз
# km_30 нашел 975 совпадений
# из 72 строк в 4 действительно есть слово картошка
# 68 неправильно предсказаных
#
#  **************************************************
#
# Всего слово рыба встрречается в df 250 раз
# km_30 нашел 729 совпадений
# из 250 строк в 9 действительно есть слово рыба
# 241 неправильно предсказаных
#
#  **************************************************
#
# Всего слово макароны встрречается в df 46 раз
# km_30 нашел 1327 совпадений
# из 46 строк в 1 действительно есть слово макароны
# 45 неправильно предсказаных
#
#  **************************************************
#
# Всего слово салат встрречается в df 2537 раз
# km_30 нашел 1327 совпадений
# из 2537 строк в 70 действительно есть слово салат
# 2467 неправильно предсказаных
#
#  **************************************************
#
#
#  **************************************************
#
# всего правильно предсказано:  285
#
#  **************************************************
#
# Всего слово суп встрречается в df 1935 раз
# km_60 нашел 1105 совпадений
# из 1935 строк в 76 действительно есть слово суп
# 1859 неправильно предсказаных
#
#  **************************************************
#
# Всего слово шашлык встрречается в df 138 раз
# km_60 нашел 652 совпадений
# из 138 строк в 4 действительно есть слово шашлык
# 134 неправильно предсказаных
#
#  **************************************************
#
# Всего слово печенье встрречается в df 585 раз
# km_60 нашел 293 совпадений
# из 585 строк в 139 действительно есть слово печенье
# 446 неправильно предсказаных
#
#  **************************************************
#
# Всего слово картошка встрречается в df 72 раз
# km_60 нашел 292 совпадений
# из 72 строк в 14 действительно есть слово картошка
# 58 неправильно предсказаных
#
#  **************************************************
#
# Всего слово рыба встрречается в df 250 раз
# km_60 нашел 381 совпадений
# из 250 строк в 12 действительно есть слово рыба
# 238 неправильно предсказаных
#
#  **************************************************
#
# Всего слово макароны встрречается в df 46 раз
# km_60 нашел 652 совпадений
# из 46 строк в 0 действительно есть слово макароны
# 46 неправильно предсказаных
#
#  **************************************************
#
# Всего слово салат встрречается в df 2537 раз
# km_60 нашел 652 совпадений
# из 2537 строк в 26 действительно есть слово салат
# 2511 неправильно предсказаных
#
#  **************************************************
#
#
#  **************************************************
#
# всего правильно предсказано:  271
#
#  **************************************************
#
# Всего слово суп встрречается в df 1935 раз
# km_90 нашел 560 совпадений
# из 1935 строк в 0 действительно есть слово суп
# 1935 неправильно предсказаных
#
#  **************************************************
#
# Всего слово шашлык встрречается в df 138 раз
# km_90 нашел 560 совпадений
# из 138 строк в 4 действительно есть слово шашлык
# 134 неправильно предсказаных
#
#  **************************************************
#
# Всего слово печенье встрречается в df 585 раз
# km_90 нашел 279 совпадений
# из 585 строк в 143 действительно есть слово печенье
# 442 неправильно предсказаных
#
#  **************************************************
#
# Всего слово картошка встрречается в df 72 раз
# km_90 нашел 253 совпадений
# из 72 строк в 10 действительно есть слово картошка
# 62 неправильно предсказаных
#
#  **************************************************
#
# Всего слово рыба встрречается в df 250 раз
# km_90 нашел 289 совпадений
# из 250 строк в 6 действительно есть слово рыба
# 244 неправильно предсказаных
#
#  **************************************************
#
# Всего слово макароны встрречается в df 46 раз
# km_90 нашел 560 совпадений
# из 46 строк в 0 действительно есть слово макароны
# 46 неправильно предсказаных
#
#  **************************************************
#
# Всего слово салат встрречается в df 2537 раз
# km_90 нашел 307 совпадений
# из 2537 строк в 275 действительно есть слово салат
# 2262 неправильно предсказаных
#
#  **************************************************
#
#
#  **************************************************
#
# всего правильно предсказано:  438
#
#  **************************************************
#
# Всего слово суп встрречается в df 1935 раз
# km_120 нашел 400 совпадений
# из 1935 строк в 36 действительно есть слово суп
# 1899 неправильно предсказаных
#
#  **************************************************
#
# Всего слово шашлык встрречается в df 138 раз
# km_120 нашел 268 совпадений
# из 138 строк в 6 действительно есть слово шашлык
# 132 неправильно предсказаных
#
#  **************************************************
#
# Всего слово печенье встрречается в df 585 раз
# km_120 нашел 137 совпадений
# из 585 строк в 46 действительно есть слово печенье
# 539 неправильно предсказаных
#
#  **************************************************
#
# Всего слово картошка встрречается в df 72 раз
# km_120 нашел 286 совпадений
# из 72 строк в 0 действительно есть слово картошка
# 72 неправильно предсказаных
#
#  **************************************************
#
# Всего слово рыба встрречается в df 250 раз
# km_120 нашел 241 совпадений
# из 250 строк в 6 действительно есть слово рыба
# 244 неправильно предсказаных
#
#  **************************************************
#
# Всего слово макароны встрречается в df 46 раз
# km_120 нашел 268 совпадений
# из 46 строк в 0 действительно есть слово макароны
# 46 неправильно предсказаных
#
#  **************************************************
#
# Всего слово салат встрречается в df 2537 раз
# km_120 нашел 208 совпадений
# из 2537 строк в 197 действительно есть слово салат
# 2340 неправильно предсказаных
#
#  **************************************************
#
#
#  **************************************************
#
# всего правильно предсказано:  291
#
#  **************************************************
#
# Всего слово суп встрречается в df 1935 раз
# km_150 нашел 289 совпадений
# из 1935 строк в 0 действительно есть слово суп
# 1935 неправильно предсказаных
#
#  **************************************************
#
# Всего слово шашлык встрречается в df 138 раз
# km_150 нашел 289 совпадений
# из 138 строк в 5 действительно есть слово шашлык
# 133 неправильно предсказаных
#
#  **************************************************
#
# Всего слово печенье встрречается в df 585 раз
# km_150 нашел 120 совпадений
# из 585 строк в 42 действительно есть слово печенье
# 543 неправильно предсказаных
#
#  **************************************************
#
# Всего слово картошка встрречается в df 72 раз
# km_150 нашел 133 совпадений
# из 72 строк в 4 действительно есть слово картошка
# 68 неправильно предсказаных
#
#  **************************************************
#
# Всего слово рыба встрречается в df 250 раз
# km_150 нашел 152 совпадений
# из 250 строк в 40 действительно есть слово рыба
# 210 неправильно предсказаных
#
#  **************************************************
#
# Всего слово макароны встрречается в df 46 раз
# km_150 нашел 289 совпадений
# из 46 строк в 0 действительно есть слово макароны
# 46 неправильно предсказаных
#
#  **************************************************
#
# Всего слово салат встрречается в df 2537 раз
# km_150 нашел 157 совпадений
# из 2537 строк в 147 действительно есть слово салат
# 2390 неправильно предсказаных
#
#  **************************************************
#
#
#  **************************************************
#
# всего правильно предсказано:  238
#
#  **************************************************
#
# Всего слово суп встрречается в df 1935 раз
# km_180 нашел 196 совпадений
# из 1935 строк в 2 действительно есть слово суп
# 1933 неправильно предсказаных
#
#  **************************************************
#
# Всего слово шашлык встрречается в df 138 раз
# km_180 нашел 100 совпадений
# из 138 строк в 4 действительно есть слово шашлык
# 134 неправильно предсказаных
#
#  **************************************************
# Всего слово печенье встрречается в df 585 раз
# km_180 нашел 121 совпадений
# из 585 строк в 59 действительно есть слово печенье
# 526 неправильно предсказаных
#
#  **************************************************
#
# Всего слово картошка встрречается в df 72 раз
# km_180 нашел 111 совпадений
# из 72 строк в 13 действительно есть слово картошка
# 59 неправильно предсказаных
#
#  **************************************************
#
# Всего слово рыба встрречается в df 250 раз
# km_180 нашел 156 совпадений
# из 250 строк в 51 действительно есть слово рыба
# 199 неправильно предсказаных
#
#  **************************************************
#
# Всего слово макароны встрречается в df 46 раз
# km_180 нашел 196 совпадений
# из 46 строк в 0 действительно есть слово макароны
# 46 неправильно предсказаных
#
#  **************************************************
#
# Всего слово салат встрречается в df 2537 раз
# km_180 нашел 188 совпадений
# из 2537 строк в 178 действительно есть слово салат
# 2359 неправильно предсказаных
#
#  **************************************************
#
#
#  **************************************************
#
# всего правильно предсказано:  307
#
#  **************************************************
#
# Всего слово суп встрречается в df 1935 раз
# km_210 нашел 233 совпадений
# из 1935 строк в 0 действительно есть слово суп
# 1935 неправильно предсказаных
#
#  **************************************************
#
# Всего слово шашлык встрречается в df 138 раз
# km_210 нашел 120 совпадений
# из 138 строк в 14 действительно есть слово шашлык
# 124 неправильно предсказаных
#
#  **************************************************
#
# Всего слово печенье встрречается в df 585 раз
# km_210 нашел 84 совпадений
# из 585 строк в 39 действительно есть слово печенье
# 546 неправильно предсказаных
#
#  **************************************************
#
# Всего слово картошка встрречается в df 72 раз
# km_210 нашел 139 совпадений
# из 72 строк в 5 действительно есть слово картошка
# 67 неправильно предсказаных
#
#  **************************************************
#
# Всего слово рыба встрречается в df 250 раз
# km_210 нашел 133 совпадений
# из 250 строк в 40 действительно есть слово рыба
# 210 неправильно предсказаных
#
#  **************************************************
#
# Всего слово макароны встрречается в df 46 раз
# km_210 нашел 233 совпадений
# из 46 строк в 0 действительно есть слово макароны
# 46 неправильно предсказаных
#
#  **************************************************
#
# Всего слово салат встрречается в df 2537 раз
# km_210 нашел 151 совпадений
# из 2537 строк в 148 действительно есть слово салат
# 2389 неправильно предсказаных
#
#  **************************************************
#
#
#  **************************************************
#
# всего правильно предсказано:  246
#
#  **************************************************
#
# Всего слово суп встрречается в df 1935 раз
# km_240 нашел 225 совпадений
# из 1935 строк в 1 действительно есть слово суп
# 1934 неправильно предсказаных
#
#  **************************************************
#
# Всего слово шашлык встрречается в df 138 раз
# km_240 нашел 142 совпадений
# из 138 строк в 4 действительно есть слово шашлык
# 134 неправильно предсказаных
#
#  **************************************************
#
# Всего слово печенье встрречается в df 585 раз
# km_240 нашел 104 совпадений
# из 585 строк в 46 действительно есть слово печенье
# 539 неправильно предсказаных
#
#  **************************************************
#
# Всего слово картошка встрречается в df 72 раз
# km_240 нашел 115 совпадений
# из 72 строк в 0 действительно есть слово картошка
# 72 неправильно предсказаных
#
#  **************************************************
#
# Всего слово рыба встрречается в df 250 раз
# km_240 нашел 122 совпадений
# из 250 строк в 36 действительно есть слово рыба
# 214 неправильно предсказаных
#
#  **************************************************
#
# Всего слово макароны встрречается в df 46 раз
# km_240 нашел 142 совпадений
# из 46 строк в 0 действительно есть слово макароны
# 46 неправильно предсказаных
#
#  **************************************************
#
# Всего слово салат встрречается в df 2537 раз
# km_240 нашел 142 совпадений
# из 2537 строк в 138 действительно есть слово салат
# 2399 неправильно предсказаных
#
#  **************************************************
#
#
#  **************************************************
#
# всего правильно предсказано:  225
#
#  **************************************************
#
# Всего слово суп встрречается в df 1935 раз
# km_270 нашел 170 совпадений
# из 1935 строк в 0 действительно есть слово суп
# 1935 неправильно предсказаных
#
#  **************************************************
#
# Всего слово шашлык встрречается в df 138 раз
# km_270 нашел 119 совпадений
# из 138 строк в 13 действительно есть слово шашлык
# 125 неправильно предсказаных
#
#  **************************************************
#
# Всего слово печенье встрречается в df 585 раз
# km_270 нашел 104 совпадений
# из 585 строк в 44 действительно есть слово печенье
# 541 неправильно предсказаных
#
#  **************************************************
#
# Всего слово картошка встрречается в df 72 раз
# km_270 нашел 218 совпадений
# из 72 строк в 0 действительно есть слово картошка
# 72 неправильно предсказаных
#
#  **************************************************
#
# Всего слово рыба встрречается в df 250 раз
# km_270 нашел 66 совпадений
# из 250 строк в 9 действительно есть слово рыба
# 241 неправильно предсказаных
#
#  **************************************************
#
# Всего слово макароны встрречается в df 46 раз
# km_270 нашел 170 совпадений
# из 46 строк в 0 действительно есть слово макароны
# 46 неправильно предсказаных
#
#  **************************************************
#
# Всего слово салат встрречается в df 2537 раз
# km_270 нашел 117 совпадений
# из 2537 строк в 112 действительно есть слово салат
# 2425 неправильно предсказаных
#
#  **************************************************
#
#
#  **************************************************
#
# всего правильно предсказано:  178
#
#  **************************************************
#
# Всего слово суп встрречается в df 1935 раз
# km_300 нашел 87 совпадений
# из 1935 строк в 0 действительно есть слово суп
# 1935 неправильно предсказаных
#
#  **************************************************
#
# Всего слово шашлык встрречается в df 138 раз
# km_300 нашел 134 совпадений
# из 138 строк в 7 действительно есть слово шашлык
# 131 неправильно предсказаных
#
#  **************************************************
#
# Всего слово печенье встрречается в df 585 раз
# km_300 нашел 165 совпадений
# из 585 строк в 114 действительно есть слово печенье
# 471 неправильно предсказаных
#
#  **************************************************
#
# Всего слово картошка встрречается в df 72 раз
# km_300 нашел 140 совпадений
# из 72 строк в 2 действительно есть слово картошка
# 70 неправильно предсказаных
#
#  **************************************************
#
# Всего слово рыба встрречается в df 250 раз
# km_300 нашел 66 совпадений
# из 250 строк в 8 действительно есть слово рыба
# 242 неправильно предсказаных
#
#  **************************************************
#
# Всего слово макароны встрречается в df 46 раз
# km_300 нашел 172 совпадений
# из 46 строк в 0 действительно есть слово макароны
# 46 неправильно предсказаных
#
#  **************************************************
#
# Всего слово салат встрречается в df 2537 раз
# km_300 нашел 106 совпадений
# из 2537 строк в 101 действительно есть слово салат
# 2436 неправильно предсказаных
#
#  **************************************************
#
#
#  **************************************************
#
# всего правильно предсказано:  232
#
#  **************************************************
#
# Всего слово суп встрречается в df 1935 раз
# km_330 нашел 132 совпадений
# из 1935 строк в 8 действительно есть слово суп
# 1927 неправильно предсказаных
#
#  **************************************************
#
# Всего слово шашлык встрречается в df 138 раз
# km_330 нашел 42 совпадений
# из 138 строк в 16 действительно есть слово шашлык
# 122 неправильно предсказаных
#
#  **************************************************
#
# Всего слово печенье встрречается в df 585 раз
# km_330 нашел 90 совпадений
# из 585 строк в 37 действительно есть слово печенье
# 548 неправильно предсказаных
#
#  **************************************************
#
# Всего слово картошка встрречается в df 72 раз
# km_330 нашел 130 совпадений
# из 72 строк в 0 действительно есть слово картошка
# 72 неправильно предсказаных
#
#  **************************************************
# Всего слово рыба встрречается в df 250 раз
# km_330 нашел 66 совпадений
# из 250 строк в 8 действительно есть слово рыба
# 242 неправильно предсказаных
#
#  **************************************************
#
# Всего слово макароны встрречается в df 46 раз
# km_330 нашел 132 совпадений
# из 46 строк в 0 действительно есть слово макароны
# 46 неправильно предсказаных
#
#  **************************************************
#
# Всего слово салат встрречается в df 2537 раз
# km_330 нашел 99 совпадений
# из 2537 строк в 96 действительно есть слово салат
# 2441 неправильно предсказаных
#
#  **************************************************
#
#
#  **************************************************
#
# всего правильно предсказано:  165
#
#  **************************************************
#
# Всего слово суп встрречается в df 1935 раз
# km_360 нашел 194 совпадений
# из 1935 строк в 40 действительно есть слово суп
# 1895 неправильно предсказаных
#
#  **************************************************
#
# Всего слово шашлык встрречается в df 138 раз
# km_360 нашел 17 совпадений
# из 138 строк в 5 действительно есть слово шашлык
# 133 неправильно предсказаных
#
#  **************************************************
#
# Всего слово печенье встрречается в df 585 раз
# km_360 нашел 63 совпадений
# из 585 строк в 36 действительно есть слово печенье
# 549 неправильно предсказаных
#
#  **************************************************
#
# Всего слово картошка встрречается в df 72 раз
# km_360 нашел 100 совпадений
# из 72 строк в 1 действительно есть слово картошка
# 71 неправильно предсказаных
#
#  **************************************************
#
# Всего слово рыба встрречается в df 250 раз
# km_360 нашел 60 совпадений
# из 250 строк в 7 действительно есть слово рыба
# 243 неправильно предсказаных
#
#  **************************************************
#
# Всего слово макароны встрречается в df 46 раз
# km_360 нашел 112 совпадений
# из 46 строк в 0 действительно есть слово макароны
# 46 неправильно предсказаных
#
#  **************************************************
#
# Всего слово салат встрречается в df 2537 раз
# km_360 нашел 129 совпадений
# из 2537 строк в 127 действительно есть слово салат
# 2410 неправильно предсказаных
#
#  **************************************************
#
#
#  **************************************************
#
# всего правильно предсказано:  216
#
#  **************************************************
#
# Всего слово суп встрречается в df 1935 раз
# km_390 нашел 69 совпадений
# из 1935 строк в 0 действительно есть слово суп
# 1935 неправильно предсказаных
#
#  **************************************************
#
# Всего слово шашлык встрречается в df 138 раз
# km_390 нашел 16 совпадений
# из 138 строк в 5 действительно есть слово шашлык
# 133 неправильно предсказаных
#
#  **************************************************
#
# Всего слово печенье встрречается в df 585 раз
# km_390 нашел 63 совпадений
# из 585 строк в 34 действительно есть слово печенье
# 551 неправильно предсказаных
#
#  **************************************************
#
# Всего слово картошка встрречается в df 72 раз
# km_390 нашел 96 совпадений
# из 72 строк в 0 действительно есть слово картошка
# 72 неправильно предсказаных
#
#  **************************************************
#
# Всего слово рыба встрречается в df 250 раз
# km_390 нашел 124 совпадений
# из 250 строк в 38 действительно есть слово рыба
# 212 неправильно предсказаных
#
#  **************************************************
#
# Всего слово макароны встрречается в df 46 раз
# km_390 нашел 164 совпадений
# из 46 строк в 0 действительно есть слово макароны
# 46 неправильно предсказаных
#
#  **************************************************
#
# Всего слово салат встрречается в df 2537 раз
# km_390 нашел 130 совпадений
# из 2537 строк в 127 действительно есть слово салат
# 2410 неправильно предсказаных
#
#  **************************************************
#
#
#  **************************************************
#
# всего правильно предсказано:  204
#
#  **************************************************
#
# Всего слово суп встрречается в df 1935 раз
# km_420 нашел 96 совпадений
# из 1935 строк в 2 действительно есть слово суп
# 1933 неправильно предсказаных
#
#  **************************************************
#
# Всего слово шашлык встрречается в df 138 раз
# km_420 нашел 45 совпадений
# из 138 строк в 4 действительно есть слово шашлык
# 134 неправильно предсказаных
#
#  **************************************************
#
# Всего слово печенье встрречается в df 585 раз
# km_420 нашел 66 совпадений
# из 585 строк в 40 действительно есть слово печенье
# 545 неправильно предсказаных
#
#  **************************************************
#
# Всего слово картошка встрречается в df 72 раз
# km_420 нашел 20 совпадений
# из 72 строк в 13 действительно есть слово картошка
# 59 неправильно предсказаных
#
#  **************************************************
#
# Всего слово рыба встрречается в df 250 раз
# km_420 нашел 123 совпадений
# из 250 строк в 34 действительно есть слово рыба
# 216 неправильно предсказаных
#
#  **************************************************
#
# Всего слово макароны встрречается в df 46 раз
# km_420 нашел 128 совпадений
# из 46 строк в 0 действительно есть слово макароны
# 46 неправильно предсказаных
#
#  **************************************************
#
# Всего слово салат встрречается в df 2537 раз
# km_420 нашел 113 совпадений
# из 2537 строк в 110 действительно есть слово салат
# 2427 неправильно предсказаных
#
#  **************************************************
#
#
#  **************************************************
#
# всего правильно предсказано:  203
#
#  **************************************************
#
# Всего слово суп встрречается в df 1935 раз
# km_450 нашел 105 совпадений
# из 1935 строк в 0 действительно есть слово суп
# 1935 неправильно предсказаных
#
#  **************************************************
#
# Всего слово шашлык встрречается в df 138 раз
# km_450 нашел 13 совпадений
# из 138 строк в 12 действительно есть слово шашлык
# 126 неправильно предсказаных
#
#  **************************************************
#
# Всего слово печенье встрречается в df 585 раз
# km_450 нашел 57 совпадений
# из 585 строк в 31 действительно есть слово печенье
# 554 неправильно предсказаных
#
#  **************************************************
#
# Всего слово картошка встрречается в df 72 раз
# km_450 нашел 25 совпадений
# из 72 строк в 13 действительно есть слово картошка
# 59 неправильно предсказаных
#
#  **************************************************
#
# Всего слово рыба встрречается в df 250 раз
# km_450 нашел 71 совпадений
# из 250 строк в 11 действительно есть слово рыба
# 239 неправильно предсказаных
#
#  **************************************************
#
# Всего слово макароны встрречается в df 46 раз
# km_450 нашел 105 совпадений
# из 46 строк в 0 действительно есть слово макароны
# 46 неправильно предсказаных
#
#  **************************************************
#
# Всего слово салат встрречается в df 2537 раз
# km_450 нашел 142 совпадений
# из 2537 строк в 138 действительно есть слово салат
# 2399 неправильно предсказаных
#
#  **************************************************
#
#
#  **************************************************
#
# всего правильно предсказано:  205
#
#  **************************************************
#
# Всего слово суп встрречается в df 1935 раз
# km_480 нашел 129 совпадений
# из 1935 строк в 24 действительно есть слово суп
# 1911 неправильно предсказаных
#
#  **************************************************
#
# Всего слово шашлык встрречается в df 138 раз
# km_480 нашел 5 совпадений
# из 138 строк в 5 действительно есть слово шашлык
# 133 неправильно предсказаных
#
#  **************************************************
#
# Всего слово печенье встрречается в df 585 раз
# km_480 нашел 46 совпадений
# из 585 строк в 25 действительно есть слово печенье
# 560 неправильно предсказаных
#
#  **************************************************
#
# Всего слово картошка встрречается в df 72 раз
# km_480 нашел 41 совпадений
# из 72 строк в 4 действительно есть слово картошка
# 68 неправильно предсказаных
#
#  **************************************************
#
# Всего слово рыба встрречается в df 250 раз
# km_480 нашел 73 совпадений
# из 250 строк в 22 действительно есть слово рыба
# 228 неправильно предсказаных
#
#  **************************************************
#
# Всего слово макароны встрречается в df 46 раз
# km_480 нашел 112 совпадений
# из 46 строк в 0 действительно есть слово макароны
# 46 неправильно предсказаных
#
#  **************************************************
# Всего слово салат встрречается в df 2537 раз
# km_480 нашел 105 совпадений
# из 2537 строк в 101 действительно есть слово салат
# 2436 неправильно предсказаных
#
#  **************************************************
#
#
#  **************************************************
#
# всего правильно предсказано:  181
#
#  **************************************************
#
# Всего слово суп встрречается в df 1935 раз
# km_510 нашел 44 совпадений
# из 1935 строк в 0 действительно есть слово суп
# 1935 неправильно предсказаных
#
#  **************************************************
#
# Всего слово шашлык встрречается в df 138 раз
# km_510 нашел 22 совпадений
# из 138 строк в 8 действительно есть слово шашлык
# 130 неправильно предсказаных
#
#  **************************************************
#
# Всего слово печенье встрречается в df 585 раз
# km_510 нашел 64 совпадений
# из 585 строк в 55 действительно есть слово печенье
# 530 неправильно предсказаных
#
#  **************************************************
#
# Всего слово картошка встрречается в df 72 раз
# km_510 нашел 60 совпадений
# из 72 строк в 3 действительно есть слово картошка
# 69 неправильно предсказаных
#
#  **************************************************
#
# Всего слово рыба встрречается в df 250 раз
# km_510 нашел 67 совпадений
# из 250 строк в 11 действительно есть слово рыба
# 239 неправильно предсказаных
#
#  **************************************************
#
# Всего слово макароны встрречается в df 46 раз
# km_510 нашел 48 совпадений
# из 46 строк в 0 действительно есть слово макароны
# 46 неправильно предсказаных
#
#  **************************************************
#
# Всего слово салат встрречается в df 2537 раз
# km_510 нашел 68 совпадений
# из 2537 строк в 65 действительно есть слово салат
# 2472 неправильно предсказаных
#
#  **************************************************
#
#
#  **************************************************
#
# всего правильно предсказано:  142
#
#  **************************************************
#
# Всего слово суп встрречается в df 1935 раз
# km_540 нашел 52 совпадений
# из 1935 строк в 0 действительно есть слово суп
# 1935 неправильно предсказаных
#
#  **************************************************
#
# Всего слово шашлык встрречается в df 138 раз
# km_540 нашел 21 совпадений
# из 138 строк в 5 действительно есть слово шашлык
# 133 неправильно предсказаных
#
#  **************************************************
#
# Всего слово печенье встрречается в df 585 раз
# km_540 нашел 52 совпадений
# из 585 строк в 35 действительно есть слово печенье
# 550 неправильно предсказаных
#
#  **************************************************
#
# Всего слово картошка встрречается в df 72 раз
# km_540 нашел 59 совпадений
# из 72 строк в 2 действительно есть слово картошка
# 70 неправильно предсказаных
#
#  **************************************************
#
# Всего слово рыба встрречается в df 250 раз
# km_540 нашел 83 совпадений
# из 250 строк в 28 действительно есть слово рыба
# 222 неправильно предсказаных
#
#  **************************************************
#
# Всего слово макароны встрречается в df 46 раз
# km_540 нашел 78 совпадений
# из 46 строк в 0 действительно есть слово макароны
# 46 неправильно предсказаных
#
#  **************************************************
#
# Всего слово салат встрречается в df 2537 раз
# km_540 нашел 75 совпадений
# из 2537 строк в 72 действительно есть слово салат
# 2465 неправильно предсказаных
#
#  **************************************************
#
#
#  **************************************************
#
# всего правильно предсказано:  142
#
#  **************************************************
#
# Всего слово суп встрречается в df 1935 раз
# km_570 нашел 110 совпадений
# из 1935 строк в 0 действительно есть слово суп
# 1935 неправильно предсказаных
#
#  **************************************************
#
# Всего слово шашлык встрречается в df 138 раз
# km_570 нашел 43 совпадений
# из 138 строк в 6 действительно есть слово шашлык
# 132 неправильно предсказаных
#
#  **************************************************
#
# Всего слово печенье встрречается в df 585 раз
# km_570 нашел 27 совпадений
# из 585 строк в 18 действительно есть слово печенье
# 567 неправильно предсказаных
#
#  **************************************************
#
# Всего слово картошка встрречается в df 72 раз
# km_570 нашел 45 совпадений
# из 72 строк в 5 действительно есть слово картошка
# 67 неправильно предсказаных
#
#  **************************************************
#
# Всего слово рыба встрречается в df 250 раз
# km_570 нашел 64 совпадений
# из 250 строк в 32 действительно есть слово рыба
# 218 неправильно предсказаных
#
#  **************************************************
#
# Всего слово макароны встрречается в df 46 раз
# km_570 нашел 110 совпадений
# из 46 строк в 0 действительно есть слово макароны
# 46 неправильно предсказаных
#
#  **************************************************
#
# Всего слово салат встрречается в df 2537 раз
# km_570 нашел 81 совпадений
# из 2537 строк в 81 действительно есть слово салат
# 2456 неправильно предсказаных
#
#  **************************************************
#
#
#  **************************************************
#
# всего правильно предсказано:  142
#
#  **************************************************
#
# Всего слово суп встрречается в df 1935 раз
# km_600 нашел 61 совпадений
# из 1935 строк в 0 действительно есть слово суп
# 1935 неправильно предсказаных
#
#  **************************************************
#
# Всего слово шашлык встрречается в df 138 раз
# km_600 нашел 11 совпадений
# из 138 строк в 11 действительно есть слово шашлык
# 127 неправильно предсказаных
#
#  **************************************************
#
# Всего слово печенье встрречается в df 585 раз
# km_600 нашел 34 совпадений
# из 585 строк в 25 действительно есть слово печенье
# 560 неправильно предсказаных
#
#  **************************************************
#
# Всего слово картошка встрречается в df 72 раз
# km_600 нашел 43 совпадений
# из 72 строк в 1 действительно есть слово картошка
# 71 неправильно предсказаных
#
#  **************************************************
#
# Всего слово рыба встрречается в df 250 раз
# km_600 нашел 39 совпадений
# из 250 строк в 3 действительно есть слово рыба
# 247 неправильно предсказаных
#
#  **************************************************
#
# Всего слово макароны встрречается в df 46 раз
# km_600 нашел 76 совпадений
# из 46 строк в 0 действительно есть слово макароны
# 46 неправильно предсказаных
#
#  **************************************************
#
# Всего слово салат встрречается в df 2537 раз
# km_600 нашел 59 совпадений
# из 2537 строк в 58 действительно есть слово салат
# 2479 неправильно предсказаных
#
#  **************************************************
#
#
#  **************************************************
#
# всего правильно предсказано:  98
#
#  **************************************************
#
# Всего слово суп встрречается в df 1935 раз
# km_630 нашел 89 совпадений
# из 1935 строк в 19 действительно есть слово суп
# 1916 неправильно предсказаных
#
#  **************************************************
#
# Всего слово шашлык встрречается в df 138 раз
# km_630 нашел 23 совпадений
# из 138 строк в 5 действительно есть слово шашлык
# 133 неправильно предсказаных
#
#  **************************************************
#
# Всего слово печенье встрречается в df 585 раз
# km_630 нашел 52 совпадений
# из 585 строк в 39 действительно есть слово печенье
# 546 неправильно предсказаных
#
#  **************************************************
#
# Всего слово картошка встрречается в df 72 раз
# km_630 нашел 24 совпадений
# из 72 строк в 13 действительно есть слово картошка
# 59 неправильно предсказаных
#
#  **************************************************
#
# Всего слово рыба встрречается в df 250 раз
# km_630 нашел 47 совпадений
# из 250 строк в 10 действительно есть слово рыба
# 240 неправильно предсказаных
#
#  **************************************************
#
# Всего слово макароны встрречается в df 46 раз
# km_630 нашел 53 совпадений
# из 46 строк в 0 действительно есть слово макароны
# 46 неправильно предсказаных
#
#  **************************************************
#
# Всего слово салат встрречается в df 2537 раз
# km_630 нашел 66 совпадений
# из 2537 строк в 64 действительно есть слово салат
# 2473 неправильно предсказаных
#
#  **************************************************
#
#
#  **************************************************
#
# всего правильно предсказано:  150
#
#  **************************************************
# Всего слово суп встрречается в df 1935 раз
# km_660 нашел 70 совпадений
# из 1935 строк в 20 действительно есть слово суп
# 1915 неправильно предсказаных
#
#  **************************************************
#
# Всего слово шашлык встрречается в df 138 раз
# km_660 нашел 6 совпадений
# из 138 строк в 6 действительно есть слово шашлык
# 132 неправильно предсказаных
#
#  **************************************************
#
# Всего слово печенье встрречается в df 585 раз
# km_660 нашел 41 совпадений
# из 585 строк в 25 действительно есть слово печенье
# 560 неправильно предсказаных
#
#  **************************************************
#
# Всего слово картошка встрречается в df 72 раз
# km_660 нашел 19 совпадений
# из 72 строк в 13 действительно есть слово картошка
# 59 неправильно предсказаных
#
#  **************************************************
#
# Всего слово рыба встрречается в df 250 раз
# km_660 нашел 47 совпадений
# из 250 строк в 10 действительно есть слово рыба
# 240 неправильно предсказаных
#
#  **************************************************
#
# Всего слово макароны встрречается в df 46 раз
# km_660 нашел 58 совпадений
# из 46 строк в 0 действительно есть слово макароны
# 46 неправильно предсказаных
#
#  **************************************************
#
# Всего слово салат встрречается в df 2537 раз
# km_660 нашел 65 совпадений
# из 2537 строк в 62 действительно есть слово салат
# 2475 неправильно предсказаных
#
#  **************************************************
#
#
#  **************************************************
#
# всего правильно предсказано:  136
#
#  **************************************************
#
# Всего слово суп встрречается в df 1935 раз
# km_690 нашел 42 совпадений
# из 1935 строк в 1 действительно есть слово суп
# 1934 неправильно предсказаных
#
#  **************************************************
#
# Всего слово шашлык встрречается в df 138 раз
# km_690 нашел 5 совпадений
# из 138 строк в 5 действительно есть слово шашлык
# 133 неправильно предсказаных
#
#  **************************************************
#
# Всего слово печенье встрречается в df 585 раз
# km_690 нашел 28 совпадений
# из 585 строк в 14 действительно есть слово печенье
# 571 неправильно предсказаных
#
#  **************************************************
#
# Всего слово картошка встрречается в df 72 раз
# km_690 нашел 56 совпадений
# из 72 строк в 0 действительно есть слово картошка
# 72 неправильно предсказаных
#
#  **************************************************
#
# Всего слово рыба встрречается в df 250 раз
# km_690 нашел 31 совпадений
# из 250 строк в 6 действительно есть слово рыба
# 244 неправильно предсказаных
#
#  **************************************************
#
# Всего слово макароны встрречается в df 46 раз
# km_690 нашел 72 совпадений
# из 46 строк в 0 действительно есть слово макароны
# 46 неправильно предсказаных
#
#  **************************************************
#
# Всего слово салат встрречается в df 2537 раз
# km_690 нашел 86 совпадений
# из 2537 строк в 84 действительно есть слово салат
# 2453 неправильно предсказаных
#
#  **************************************************
#
#
#  **************************************************
#
# всего правильно предсказано:  110
#
#  **************************************************
#
# Всего слово суп встрречается в df 1935 раз
# km_720 нашел 29 совпадений
# из 1935 строк в 0 действительно есть слово суп
# 1935 неправильно предсказаных
#
#  **************************************************
#
# Всего слово шашлык встрречается в df 138 раз
# km_720 нашел 10 совпадений
# из 138 строк в 10 действительно есть слово шашлык
# 128 неправильно предсказаных
#
#  **************************************************
#
# Всего слово печенье встрречается в df 585 раз
# km_720 нашел 46 совпадений
# из 585 строк в 30 действительно есть слово печенье
# 555 неправильно предсказаных
#
#  **************************************************
#
# Всего слово картошка встрречается в df 72 раз
# km_720 нашел 42 совпадений
# из 72 строк в 0 действительно есть слово картошка
# 72 неправильно предсказаных
#
#  **************************************************
#
# Всего слово рыба встрречается в df 250 раз
# km_720 нашел 81 совпадений
# из 250 строк в 18 действительно есть слово рыба
# 232 неправильно предсказаных
#
#  **************************************************
#
# Всего слово макароны встрречается в df 46 раз
# km_720 нашел 45 совпадений
# из 46 строк в 0 действительно есть слово макароны
# 46 неправильно предсказаных
#
#  **************************************************
#
# Всего слово салат встрречается в df 2537 раз
# km_720 нашел 89 совпадений
# из 2537 строк в 87 действительно есть слово салат
# 2450 неправильно предсказаных
#
#  **************************************************
#
#
#  **************************************************
#
# всего правильно предсказано:  145
#
#  **************************************************
#
# Всего слово суп встрречается в df 1935 раз
# km_750 нашел 88 совпадений
# из 1935 строк в 75 действительно есть слово суп
# 1860 неправильно предсказаных
#
#  **************************************************
#
# Всего слово шашлык встрречается в df 138 раз
# km_750 нашел 16 совпадений
# из 138 строк в 5 действительно есть слово шашлык
# 133 неправильно предсказаных
#
#  **************************************************
#
# Всего слово печенье встрречается в df 585 раз
# km_750 нашел 36 совпадений
# из 585 строк в 25 действительно есть слово печенье
# 560 неправильно предсказаных
#
#  **************************************************
#
# Всего слово картошка встрречается в df 72 раз
# km_750 нашел 26 совпадений
# из 72 строк в 5 действительно есть слово картошка
# 67 неправильно предсказаных
#
#  **************************************************
#
# Всего слово рыба встрречается в df 250 раз
# km_750 нашел 49 совпадений
# из 250 строк в 5 действительно есть слово рыба
# 245 неправильно предсказаных
#
#  **************************************************
#
# Всего слово макароны встрречается в df 46 раз
# km_750 нашел 58 совпадений
# из 46 строк в 0 действительно есть слово макароны
# 46 неправильно предсказаных
#
#  **************************************************
#
# Всего слово салат встрречается в df 2537 раз
# km_750 нашел 38 совпадений
# из 2537 строк в 32 действительно есть слово салат
# 2505 неправильно предсказаных
#
#  **************************************************
#
#
#  **************************************************
#
# всего правильно предсказано:  147
#
#  **************************************************
#
# Всего слово суп встрречается в df 1935 раз
# km_780 нашел 73 совпадений
# из 1935 строк в 21 действительно есть слово суп
# 1914 неправильно предсказаных
#
#  **************************************************
#
# Всего слово шашлык встрречается в df 138 раз
# km_780 нашел 16 совпадений
# из 138 строк в 5 действительно есть слово шашлык
# 133 неправильно предсказаных
#
#  **************************************************
#
# Всего слово печенье встрречается в df 585 раз
# km_780 нашел 43 совпадений
# из 585 строк в 29 действительно есть слово печенье
# 556 неправильно предсказаных
#
#  **************************************************
#
# Всего слово картошка встрречается в df 72 раз
# km_780 нашел 18 совпадений
# из 72 строк в 5 действительно есть слово картошка
# 67 неправильно предсказаных
#
#  **************************************************
#
# Всего слово рыба встрречается в df 250 раз
# km_780 нашел 41 совпадений
# из 250 строк в 10 действительно есть слово рыба
# 240 неправильно предсказаных
#
#  **************************************************
#
# Всего слово макароны встрречается в df 46 раз
# km_780 нашел 63 совпадений
# из 46 строк в 0 действительно есть слово макароны
# 46 неправильно предсказаных
#
#  **************************************************
#
# Всего слово салат встрречается в df 2537 раз
# km_780 нашел 69 совпадений
# из 2537 строк в 68 действительно есть слово салат
# 2469 неправильно предсказаных
#
#  **************************************************
#
#
#  **************************************************
#
# всего правильно предсказано:  138
#
#  **************************************************
#
# Всего слово суп встрречается в df 1935 раз
# km_810 нашел 89 совпадений
# из 1935 строк в 61 действительно есть слово суп
# 1874 неправильно предсказаных
#
#  **************************************************
#
# Всего слово шашлык встрречается в df 138 раз
# km_810 нашел 16 совпадений
# из 138 строк в 5 действительно есть слово шашлык
# 133 неправильно предсказаных
#
#  **************************************************
# Всего слово печенье встрречается в df 585 раз
# km_810 нашел 40 совпадений
# из 585 строк в 39 действительно есть слово печенье
# 546 неправильно предсказаных
#
#  **************************************************
#
# Всего слово картошка встрречается в df 72 раз
# km_810 нашел 35 совпадений
# из 72 строк в 3 действительно есть слово картошка
# 69 неправильно предсказаных
#
#  **************************************************
#
# Всего слово рыба встрречается в df 250 раз
# km_810 нашел 49 совпадений
# из 250 строк в 15 действительно есть слово рыба
# 235 неправильно предсказаных
#
#  **************************************************
#
# Всего слово макароны встрречается в df 46 раз
# km_810 нашел 55 совпадений
# из 46 строк в 0 действительно есть слово макароны
# 46 неправильно предсказаных
#
#  **************************************************
#
# Всего слово салат встрречается в df 2537 раз
# km_810 нашел 44 совпадений
# из 2537 строк в 42 действительно есть слово салат
# 2495 неправильно предсказаных
#
#  **************************************************
#
#
#  **************************************************
#
# всего правильно предсказано:  165
#
#  **************************************************
#
# Всего слово суп встрречается в df 1935 раз
# km_840 нашел 62 совпадений
# из 1935 строк в 20 действительно есть слово суп
# 1915 неправильно предсказаных
#
#  **************************************************
#
# Всего слово шашлык встрречается в df 138 раз
# km_840 нашел 16 совпадений
# из 138 строк в 5 действительно есть слово шашлык
# 133 неправильно предсказаных
#
#  **************************************************
#
# Всего слово печенье встрречается в df 585 раз
# km_840 нашел 52 совпадений
# из 585 строк в 43 действительно есть слово печенье
# 542 неправильно предсказаных
#
#  **************************************************
#
# Всего слово картошка встрречается в df 72 раз
# km_840 нашел 29 совпадений
# из 72 строк в 3 действительно есть слово картошка
# 69 неправильно предсказаных
#
#  **************************************************
#
# Всего слово рыба встрречается в df 250 раз
# km_840 нашел 28 совпадений
# из 250 строк в 3 действительно есть слово рыба
# 247 неправильно предсказаных
#
#  **************************************************
#
# Всего слово макароны встрречается в df 46 раз
# km_840 нашел 41 совпадений
# из 46 строк в 0 действительно есть слово макароны
# 46 неправильно предсказаных
#
#  **************************************************
#
# Всего слово салат встрречается в df 2537 раз
# km_840 нашел 42 совпадений
# из 2537 строк в 40 действительно есть слово салат
# 2497 неправильно предсказаных
#
#  **************************************************
#
#
#  **************************************************
#
# всего правильно предсказано:  114
#
#  **************************************************
#
# Всего слово суп встрречается в df 1935 раз
# km_870 нашел 79 совпадений
# из 1935 строк в 59 действительно есть слово суп
# 1876 неправильно предсказаных
#
#  **************************************************
#
# Всего слово шашлык встрречается в df 138 раз
# km_870 нашел 5 совпадений
# из 138 строк в 5 действительно есть слово шашлык
# 133 неправильно предсказаных
#
#  **************************************************
#
# Всего слово печенье встрречается в df 585 раз
# km_870 нашел 11 совпадений
# из 585 строк в 9 действительно есть слово печенье
# 576 неправильно предсказаных
#
#  **************************************************
#
# Всего слово картошка встрречается в df 72 раз
# km_870 нашел 28 совпадений
# из 72 строк в 5 действительно есть слово картошка
# 67 неправильно предсказаных
#
#  **************************************************
#
# Всего слово рыба встрречается в df 250 раз
# km_870 нашел 25 совпадений
# из 250 строк в 1 действительно есть слово рыба
# 249 неправильно предсказаных
#
#  **************************************************
#
# Всего слово макароны встрречается в df 46 раз
# km_870 нашел 30 совпадений
# из 46 строк в 0 действительно есть слово макароны
# 46 неправильно предсказаных
#
#  **************************************************
#
# Всего слово салат встрречается в df 2537 раз
# km_870 нашел 57 совпадений
# из 2537 строк в 57 действительно есть слово салат
# 2480 неправильно предсказаных
#
#  **************************************************
#
#
#  **************************************************
#
# всего правильно предсказано:  136
#
#  **************************************************
#
# Всего слово суп встрречается в df 1935 раз
# km_900 нашел 19 совпадений
# из 1935 строк в 14 действительно есть слово суп
# 1921 неправильно предсказаных
#
#  **************************************************
#
# Всего слово шашлык встрречается в df 138 раз
# km_900 нашел 16 совпадений
# из 138 строк в 5 действительно есть слово шашлык
# 133 неправильно предсказаных
#
#  **************************************************
#
# Всего слово печенье встрречается в df 585 раз
# km_900 нашел 24 совпадений
# из 585 строк в 21 действительно есть слово печенье
# 564 неправильно предсказаных
#
#  **************************************************
#
# Всего слово картошка встрречается в df 72 раз
# km_900 нашел 23 совпадений
# из 72 строк в 4 действительно есть слово картошка
# 68 неправильно предсказаных
#
#  **************************************************
#
# Всего слово рыба встрречается в df 250 раз
# km_900 нашел 25 совпадений
# из 250 строк в 1 действительно есть слово рыба
# 249 неправильно предсказаных
#
#  **************************************************
#
# Всего слово макароны встрречается в df 46 раз
# km_900 нашел 60 совпадений
# из 46 строк в 0 действительно есть слово макароны
# 46 неправильно предсказаных
#
#  **************************************************
#
# Всего слово салат встрречается в df 2537 раз
# km_900 нашел 51 совпадений
# из 2537 строк в 35 действительно есть слово салат
# 2502 неправильно предсказаных
#
#  **************************************************
#
#
#  **************************************************
#
# всего правильно предсказано:  80
#
#  **************************************************
#
# Всего слово суп встрречается в df 1935 раз
# km_930 нашел 71 совпадений
# из 1935 строк в 9 действительно есть слово суп
# 1926 неправильно предсказаных
#
#  **************************************************
#
# Всего слово шашлык встрречается в df 138 раз
# km_930 нашел 6 совпадений
# из 138 строк в 6 действительно есть слово шашлык
# 132 неправильно предсказаных
#
#  **************************************************
#
# Всего слово печенье встрречается в df 585 раз
# km_930 нашел 47 совпадений
# из 585 строк в 34 действительно есть слово печенье
# 551 неправильно предсказаных
#
#  **************************************************
#
# Всего слово картошка встрречается в df 72 раз
# km_930 нашел 26 совпадений
# из 72 строк в 4 действительно есть слово картошка
# 68 неправильно предсказаных
#
#  **************************************************
#
# Всего слово рыба встрречается в df 250 раз
# km_930 нашел 38 совпадений
# из 250 строк в 7 действительно есть слово рыба
# 243 неправильно предсказаных
#
#  **************************************************
#
# Всего слово макароны встрречается в df 46 раз
# km_930 нашел 51 совпадений
# из 46 строк в 0 действительно есть слово макароны
# 46 неправильно предсказаных
#
#  **************************************************
#
# Всего слово салат встрречается в df 2537 раз
# km_930 нашел 31 совпадений
# из 2537 строк в 28 действительно есть слово салат
# 2509 неправильно предсказаных
#
#  **************************************************
#
#
#  **************************************************
#
# всего правильно предсказано:  88
#
#  **************************************************
#
# Всего слово суп встрречается в df 1935 раз
# km_960 нашел 117 совпадений
# из 1935 строк в 36 действительно есть слово суп
# 1899 неправильно предсказаных
#
#  **************************************************
#
# Всего слово шашлык встрречается в df 138 раз
# km_960 нашел 5 совпадений
# из 138 строк в 5 действительно есть слово шашлык
# 133 неправильно предсказаных
#
#  **************************************************
#
# Всего слово печенье встрречается в df 585 раз
# km_960 нашел 44 совпадений
# из 585 строк в 35 действительно есть слово печенье
# 550 неправильно предсказаных
#
#  **************************************************
#
# Всего слово картошка встрречается в df 72 раз
# km_960 нашел 22 совпадений
# из 72 строк в 4 действительно есть слово картошка
# 68 неправильно предсказаных
#
#  **************************************************
# Всего слово рыба встрречается в df 250 раз
# km_960 нашел 23 совпадений
# из 250 строк в 0 действительно есть слово рыба
# 250 неправильно предсказаных
#
#  **************************************************
#
# Всего слово макароны встрречается в df 46 раз
# km_960 нашел 44 совпадений
# из 46 строк в 0 действительно есть слово макароны
# 46 неправильно предсказаных
#
#  **************************************************
#
# Всего слово салат встрречается в df 2537 раз
# km_960 нашел 34 совпадений
# из 2537 строк в 32 действительно есть слово салат
# 2505 неправильно предсказаных
#
#  **************************************************
#
#
#  **************************************************
#
# всего правильно предсказано:  112
#
#  **************************************************
#
# Всего слово суп встрречается в df 1935 раз
# km_990 нашел 71 совпадений
# из 1935 строк в 56 действительно есть слово суп
# 1879 неправильно предсказаных
#
#  **************************************************
#
# Всего слово шашлык встрречается в df 138 раз
# km_990 нашел 15 совпадений
# из 138 строк в 4 действительно есть слово шашлык
# 134 неправильно предсказаных
#
#  **************************************************
#
# Всего слово печенье встрречается в df 585 раз
# km_990 нашел 21 совпадений
# из 585 строк в 16 действительно есть слово печенье
# 569 неправильно предсказаных
#
#  **************************************************
#
# Всего слово картошка встрречается в df 72 раз
# km_990 нашел 19 совпадений
# из 72 строк в 2 действительно есть слово картошка
# 70 неправильно предсказаных
#
#  **************************************************
#
# Всего слово рыба встрречается в df 250 раз
# km_990 нашел 26 совпадений
# из 250 строк в 2 действительно есть слово рыба
# 248 неправильно предсказаных
#
#  **************************************************
#
# Всего слово макароны встрречается в df 46 раз
# km_990 нашел 38 совпадений
# из 46 строк в 0 действительно есть слово макароны
# 46 неправильно предсказаных
#
#  **************************************************
#
# Всего слово салат встрречается в df 2537 раз
# km_990 нашел 59 совпадений
# из 2537 строк в 57 действительно есть слово салат
# 2480 неправильно предсказаных
#
#  **************************************************
#
#
#  **************************************************
#
# всего правильно предсказано:  137
#
#  **************************************************
#
# [('салат', 2537), ('суп', 1935), ('печенье', 585), ('km_90', 438), ('km_180', 307), ('km_120', 291), ('km_30', 285), ('km_60', 271), ('рыба', 250), ('km_210', 246), ('km_150', 238), ('km_300', 232), ('km_240', 225), ('km_360', 216), ('km_450', 205), ('km_390', 204), ('km_420', 203), ('km_480', 181), ('km_270', 178), ('km_330', 165), ('km_810', 165), ('km_630', 150), ('km_750', 147), ('km_720', 145), ('km_510', 142), ('km_540', 142), ('km_570', 142), ('шашлык', 138), ('km_780', 138), ('km_990', 137), ('km_660', 136), ('km_870', 136), ('km_840', 114), ('km_960', 112), ('km_690', 110), ('km_600', 98), ('km_930', 88), ('km_900', 80), ('картошка', 72), ('макароны', 46)]
# Wall time: 5min 37s

# %% [markdown]
# ## 90 кластеров показали лучший результат

# %%
print(sort_dict)
# Out:
# [('салат', 2537), ('суп', 1935), ('печенье', 585), ('km_90', 438), ('km_180', 307), ('km_120', 291), ('km_30', 285), ('km_60', 271), ('рыба', 250), ('km_210', 246), ('km_150', 238), ('km_300', 232), ('km_240', 225), ('km_360', 216), ('km_450', 205), ('km_390', 204), ('km_420', 203), ('km_480', 181), ('km_270', 178), ('km_330', 165), ('km_810', 165), ('km_630', 150), ('km_750', 147), ('km_720', 145), ('km_510', 142), ('km_540', 142), ('km_570', 142), ('шашлык', 138), ('km_780', 138), ('km_990', 137), ('km_660', 136), ('km_870', 136), ('km_840', 114), ('km_960', 112), ('km_690', 110), ('km_600', 98), ('km_930', 88), ('km_900', 80), ('картошка', 72), ('макароны', 46)]
